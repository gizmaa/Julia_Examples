# %%
# Julia 0.2 RC1
# Created: October 29, 2013
# Last Edit: October 31, 2013

using PyPlot

#################
#  Create Data  #
#################
x = randn(1000) # Values
nbins = 50 # Number of bins
# Out:
# 50

# %%
##########
#  Plot  #
##########
fig = figure(figsize=(10,10)) # Not strictly required
ax = axes() # Not strictly required
h = PyPlot.plt.hist(x,nbins) # Histogram, PyPlot.plt required to differentiate with conflicting hist command

grid("on")
xlabel("X")
ylabel("Y")
title("Histogram")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x00000000196C1B00>)
# PyObject <matplotlib.text.Text object at 0x0000000021413A20>
