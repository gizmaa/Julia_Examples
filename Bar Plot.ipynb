# %%
# Julia 0.2 RC1
# Created: October 29, 2013
# Last Edit: October 31, 2013

using PyPlot

#################
#  Create Data  #
#################
x = [1:1:50]
y = 100*rand(50);

# %%
################
##  Bar Plot  ##
################
fig = figure(figsize=(10,10))
subplot(211)
b = bar(x,y,color="#0f87bf",align="center",alpha=0.4)
axis("tight")
title("Vertical Bar Plot")
grid("on")
xlabel("X")
ylabel("Y")

subplot(212)
b = barh(x,y,color="#0f87bf",align="center",alpha=0.4)

axis("tight")
title("Horizontal Bar Plot")
grid("on")
xlabel("X")
ylabel("Y")

suptitle("Bar Plot Examples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000001A39DE10>)
# PyObject <matplotlib.text.Text object at 0x000000001C38C6A0>
