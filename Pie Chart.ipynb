# %%
# Julia 0.2 RC1
# Created: October 29, 2013
# Last Edit: October 31, 2013

using PyPlot

#################
#  Create Data  #
#################
labels = ["Lager","Pilsner","Stout","IPA"]
colors = ["yellowgreen","gold","lightskyblue","lightcoral"]
sizes = NaN*zeros(4)
explode = zeros(length(sizes))
explode[round(length(sizes)*rand(1))] = 0.1
sizes = [15, 30, 45, 10]
# Out:
# 4-element Array{Int64,1}:
#  15
#  30
#  45
#  10

# %%
###############
#  Pie Chart  #
###############
fig = figure(figsize=(10,10))
p = pie(sizes,labels=labels,shadow=true,startangle=90,explode=explode,colors=colors,autopct="%1.1f%%")

axis("equal")
title("Beer")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x0000000014EFE0B8>)
# PyObject <matplotlib.text.Text object at 0x000000001E456390>
