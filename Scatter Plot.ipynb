# %%
# Julia 0.2 RC1
# Created: October 29, 2013
# Last Edit: October 31, 2013

using PyPlot

#################
#  Create Data  #
#################
x = 100*rand(50)
y = 100*rand(50)
areas = 800*rand(50)
# Out:
# 50-element Array{Float64,1}:
#  376.964
#  735.855
#  699.948
#  252.983
#   59.1007
#  278.534
#  425.812
#  265.624
#   56.6088
#  499.075
#  440.195
#  725.175
#  703.022
#    ⋮
#  657.849
#  213.245
#   49.7828
#  485.03
#  176.99
#  712.135
#   23.3852
#  757.934
#  310.461
#  417.812
#  320.906
#  170.712

# %%
##################
#  Scatter Plot  #
##################
fig = figure(figsize=(10,10))
ax = axes()
scatter(x,y,s=areas,alpha=0.5)

title("Scatter Plot")
xlabel("X")
ylabel("Y")
grid("on")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x000000001A9B0B00>)
